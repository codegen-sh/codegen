# %%
from app.generated.sdk.openapi_client.api_client import ApiClient
from app.generated.sdk.openapi_client.configuration import Configuration


ApiClient(configuration=Configuration(access_token="", host="https://codegen-sh--rest-api.modal.run/")
