# %%
# %load_ext autoreload
# %autoreload 2

# %%
import ast
from codegen.cli.utils.function_finder import CodegenFunctionVisitor


with open("/Users/christinewang/git/codegen-sdk/.codegen/codemods/test_codemod/test_codemod.py") as f:
    file_content = f.read()
    tree = ast.parse(file_content)

# Find all codegen.function decorators
visitor = CodegenFunctionVisitor()
visitor.file_content = file_content
visitor.visit(tree)
