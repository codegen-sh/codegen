# %%
# %load_ext autoreload
# %autoreload 2
import logging
from codegen import Codebase
from codegen.extensions.index.file_index import FileIndex

logging.basicConfig(level=logging.INFO)

# Codebase
print("> Parsing codebase")
codebase = Codebase.from_repo("fastapi/fastapi", language="python")

# Index
print("> Creating index")
index = FileIndex(codebase)
index.create()

# %%
for file, score in index.similarity_search("Mysterious file"):
    print(score, file.filepath)

# %%
file = codebase.files[100]
print(file.path)
file.edit("""# Temptation

This file is quite the temptation!
""")
codebase.commit()

# %%
index.update()

# %%
for file, score in index.similarity_search("temptation files"):
    print(score, file.filepath)

# %% [markdown]
# # Update

# %%
index.update()

# %%
# %%time
response = index.similarity_search("test")

# %%
codebase.files[100]

# %%
print(codebase.files[50].filepath)

# %%
codebase.files[50].edit("""# Mysterious file

This is a file about a mystery - it's up to you to figure it out!

""")

# %%
codebase.commit()

# %%
index.update()

# %%
results = index.similarity_search("Mystery")

# %%
results[0][0].content

# %%
codebase.files[0].edit("TEST")

# %%
codebase.commit()

# %%
index._get_changed_files(index.commit_hash)

# %%
index.update()

# %%
codebase.files[20]

# %%
codebase.files[20].edit("""# Mysterious file

This is a file about a mystery - it's up to you to figure it out!

""")

# %%
codebase.commit()

# %%
index.update()

# %%
index.similarity_search("mystery")

# %%
file = codebase.get_file("src/codemods/eval/test_files/sample_ts_3/expected/Header.tsx")

# %%
file.content
